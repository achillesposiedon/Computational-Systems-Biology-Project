# %%
import pandas as pd
import numpy as np

trdt1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/TrainingGenotype.csv')
trdt=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_TrainingData/DREAM5_SysGenB_TrainingExpressionData.csv')
tstdt=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_TestData/DREAM5_SysGenB2_TestExpressionData.csv')

trdt.drop('A', axis=1, inplace=True)
trdt=np.array(trdt)
trdt=np.transpose(trdt)
trdt=pd.DataFrame(trdt)

tstdt.drop('A', axis=1, inplace=True)
tstdt=np.array(tstdt)
tstdt=np.transpose(tstdt)
tstdt=pd.DataFrame(tstdt)

features=trdt.copy()

testfeatures=tstdt.copy()

results1=trdt1['Phenotype1']
results2=trdt1['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)
# Out:
#     RIL1    RIL2    RIL3    RIL4   RIL5   RIL6    RIL7    RIL8    RIL9  \
# 0  6.826  5.6850  6.5995   6.572  6.494  6.561  7.8275  7.4775  6.2810
# 1  7.888  6.2360  7.1575   7.072  7.415  7.498  7.5240  7.7220  6.9755
# 2  9.916  9.3785  9.5100  10.013  9.513  9.883  9.6205  9.7265  9.4415
# 3  8.479  8.3705  8.7735   8.544  8.662  7.715  8.2885  8.6725  8.6155
# 4  6.918  9.2905  7.6870   9.136  6.823  8.645  8.0195  6.5315  9.8405
#
#     RIL10  ...  RIL191  RIL192  RIL193  RIL194  RIL195  RIL196  RIL197  \
# 0   7.984  ...  8.1990  6.1930  7.3105  4.2995  7.4045  5.8650   7.247
# 1   7.038  ...  7.9190  7.8355  7.2645  5.3955  7.6295  6.9970   7.257
# 2  10.165  ...  9.9425  9.7550  9.5045  9.5075  9.7490  9.4625   9.748
# 3   8.887  ...  7.6880  8.5385  8.2260  8.2650  8.6015  8.0005   8.708
# 4   8.060  ...  7.7775  8.0520  8.4360  8.9415  7.3840  7.6130   8.566
#
#    RIL198  RIL199  RIL200
# 0  7.0595   7.357  6.3580
# 1  7.4225   7.209  7.9060
# 2  9.4670   9.786  9.4910
# 3  8.6300   7.878  8.8185
# 4  6.4420   9.859  8.2520
#
# [5 rows x 200 columns]
# (28395, 200)
#      RIL1   RIL2    RIL3    RIL4   RIL5    RIL6    RIL7    RIL8    RIL9  \
# 0  6.4100  7.360  7.6835  6.3765  7.444  6.1395  6.4780  7.2810  6.7270
# 1  7.9180  7.841  7.3145  6.9210  7.283  7.5395  7.3740  7.8465  7.5315
# 2  9.5210  9.703  9.8285  9.7840  9.645  9.7530  9.4130  9.5225  9.4155
# 3  8.0685  8.167  8.2020  8.2210  8.314  8.7420  8.6795  8.5480  8.1095
# 4  6.5825  6.959  8.2355  8.2175  7.195  7.3760  7.6390  6.7595  8.7610
#
#     RIL10  ...   RIL21   RIL22   RIL23  RIL24   RIL25  RIL26   RIL27  RIL28  \
# 0  6.1315  ...  6.4270  6.2600  7.8255  7.438  7.0620  5.214  7.2390  6.823
# 1  6.9720  ...  7.6640  7.4760  7.3970  7.584  7.4150  7.016  7.2185  6.887
# 2  9.5220  ...  9.4885  9.7090  9.9690  9.704  9.6545  9.569  9.6720  9.503
# 3  8.4940  ...  8.5910  8.5630  8.2945  8.773  8.4305  8.269  8.1285  8.876
# 4  8.4075  ...  7.4840  7.7915  7.8420  7.219  8.2135  9.835  7.5440  9.708
#
#    RIL29   RIL30
# 0  6.642  6.5805
# 1  7.724  7.0170
# 2  9.561  9.6845
# 3  8.556  8.4165
# 4  6.835  7.6580
#
# [5 rows x 30 columns]
# (28395, 30)

# %%
from sklearn import linear_model

lmr = linear_model.LinearRegression()
lgr2= linear_model.LinearRegression()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('LinearRegressionPredictions1.csv')

from sklearn import linear_model

lmr = linear_model.LinearRegression()
lgr2= linear_model.LinearRegression()

modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('LinearRegressionPredictions2.csv')
# Out:
# 1.1563691747703281e-15Training error
# 1.1563691747703281e-15Testing Error
# score 1.0
# score -0.5402694577803511
# 1.442123116172876e-14Training error
# 1.442123116172876e-14Testing Error
# score 1.0
# score -1.059721680416159

# %%
from sklearn import linear_model

lmr = linear_model.Lasso(alpha=0.1)
lgr2= linear_model.Lasso(alpha=0.1)

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('LassoRegressionPredictions1.csv')

from sklearn import linear_model

lmr = linear_model.Lasso(alpha=0.1)
lgr2= linear_model.Lasso(alpha=0.1)

modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('LassoRegressionPredictions2.csv')
# Out:
# 0.30958647295173264Training error
# 0.30958647295173264Testing Error
# score 0.0
# score -0.05403792526610163
# 1.4194235130049553Training error
# 1.4194235130049553Testing Error
# score 0.8828733439569082
# score -0.7430717501003336

# %%
from sklearn.tree import DecisionTreeRegressor

lmr = DecisionTreeRegressor(criterion='mse')
lgr2= DecisionTreeRegressor(criterion='mse')

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('DecisionTreeRegressionPredictions1.csv')


lmr = DecisionTreeRegressor(criterion='mse')
lgr2= DecisionTreeRegressor(criterion='mse')


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('DecisionTreeRegressionPredictions2.csv')
# Out:
# 2.988071523335655e-05Training error
# 2.988071523335655e-05Testing Error
# score 0.9999999906842457
# score -0.7075081583558869
# 0.0Training error
# 0.0Testing Error
# score 1.0
# score -1.6523026295190202

# %%
from sklearn.ensemble import RandomForestRegressor

lmr=RandomForestRegressor(n_estimators = 100, random_state = 42)
lgr2= RandomForestRegressor(n_estimators = 100, random_state = 42)

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('RandomForestRegressionPredictions1.csv')


lmr = RandomForestRegressor(n_estimators = 100, random_state = 42)
lgr2= RandomForestRegressor(n_estimators = 100, random_state = 42)


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('RandomForestRegressionPredictions2.csv')
# Out:
# 0.12120475386501074Training error
# 0.12120475386501074Testing Error
# score 0.8467235775717621
# score -0.013839744498673312
# 1.668562957268811Training error
# 1.668562957268811Testing Error
# score 0.8381484175767783
# score 0.010679134796496403

# %%
from sklearn import linear_model
lmr=linear_model.Ridge(alpha=0.5)
lgr2= linear_model.Ridge(alpha=0.5)

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('RidgeRegressionPredictions1.csv')


lmr = linear_model.Ridge(alpha=0.5)
lgr2= linear_model.Ridge(alpha=0.5)


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('RidgeRegressionPredictions2.csv')
# Out:
# 0.0008639644271422836Training error
# 0.0008639644271422836Testing Error
# score 0.999992211967241
# score -0.5380694459733513
# 0.01107337491529635Training error
# 0.01107337491529635Testing Error
# score 0.9999928716049061
# score -1.0533995323165914

# %%
from sklearn import svm

lmr=svm.SVR()
lgr2= svm.SVR()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('SVMRegressionPredictions1.csv')


lmr = svm.SVR()
lgr2= svm.SVR()


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('SVMRegressionPredictions2.csv')
# Out:
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.13025881491269098Training error
# 0.13025881491269098Testing Error
# score 0.8229686046107016
# score -0.017911294415250856
# 3.5433686706382703Training error
# 3.5433686706382703Testing Error
# score 0.27009819763459786
# score 0.028563367462457027

# %%
from sklearn.ensemble import AdaBoostRegressor

lmr=AdaBoostRegressor()
lgr2= AdaBoostRegressor()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('AdaboostRegressionPredictions1.csv')


lmr = AdaBoostRegressor()
lgr2= AdaBoostRegressor()


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('AdaboostRegressionPredictions2.csv')
# Out:
# 0.14165543907385775Training error
# 0.14165543907385775Testing Error
# score 0.7906357352285787
# score -0.05373549251823451
# 2.1404020434507025Training error
# 2.1404020434507025Testing Error
# score 0.7336685411306303
# score -0.21680272868828898

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn import tree

lmr= BaggingRegressor(tree.DecisionTreeRegressor(random_state=1))
lgr2= BaggingRegressor(tree.DecisionTreeRegressor(random_state=1))

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('baggingRegressionPredictions1.csv')


lmr = BaggingRegressor(tree.DecisionTreeRegressor(random_state=1))
lgr2= BaggingRegressor(tree.DecisionTreeRegressor(random_state=1))


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('BaggingRegressionPredictions2.csv')
# Out:
# 0.1506606618243435Training error
# 0.1506606618243435Testing Error
# score 0.7631705049774875
# score -0.07220593095284311
# 1.885510835399976Training error
# 1.885510835399976Testing Error
# score 0.7933241087380787
# score -0.1742488270362017

# %%
from sklearn.ensemble import GradientBoostingRegressor

lmr= GradientBoostingRegressor()
lgr2= GradientBoostingRegressor()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('GBMRegressionPredictions1.csv')


lmr = GradientBoostingRegressor()
lgr2= GradientBoostingRegressor()


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('GBMRegressionPredictions2.csv')
# Out:
# 0.0142708459003577Training error
# 0.0142708459003577Testing Error
# score 0.9978751147574364
# score -0.10963056415819117
# 0.21025840826090925Training error
# 0.21025840826090925Testing Error
# score 0.9974299681898617
# score -0.1262780626119735

# %%
from catboost import CatBoostRegressor

lmr= CatBoostRegressor()
lgr2= CatBoostRegressor()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('CatBoostRegressionPredictions1.csv')


lmr = CatBoostRegressor()
lgr2= CatBoostRegressor()


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('CatBoostRegressionPredictions2.csv')
# Out:
# Learning rate set to 0.029308
# 0:	learn: 0.3317091	total: 90.8ms	remaining: 1m 30s
# 1:	learn: 0.3298378	total: 130ms	remaining: 1m 4s
# 2:	learn: 0.3277431	total: 154ms	remaining: 51.1s
# 3:	learn: 0.3257137	total: 168ms	remaining: 41.9s
# 4:	learn: 0.3238353	total: 181ms	remaining: 36.1s
# 5:	learn: 0.3221274	total: 194ms	remaining: 32.1s
# 6:	learn: 0.3199091	total: 206ms	remaining: 29.2s
# 7:	learn: 0.3177628	total: 233ms	remaining: 28.9s
# 8:	learn: 0.3160992	total: 247ms	remaining: 27.2s
# 9:	learn: 0.3139354	total: 261ms	remaining: 25.8s
# 10:	learn: 0.3117400	total: 273ms	remaining: 24.6s
# 11:	learn: 0.3095337	total: 292ms	remaining: 24.1s
# 12:	learn: 0.3074844	total: 308ms	remaining: 23.4s
# 13:	learn: 0.3056003	total: 320ms	remaining: 22.5s
# 14:	learn: 0.3035581	total: 333ms	remaining: 21.9s
# 15:	learn: 0.3014468	total: 346ms	remaining: 21.3s
# 16:	learn: 0.2999775	total: 359ms	remaining: 20.8s
# 17:	learn: 0.2982461	total: 371ms	remaining: 20.2s
# 18:	learn: 0.2965659	total: 383ms	remaining: 19.8s
# 19:	learn: 0.2944561	total: 398ms	remaining: 19.5s
# 20:	learn: 0.2928838	total: 411ms	remaining: 19.1s
# 21:	learn: 0.2910103	total: 426ms	remaining: 18.9s
# 22:	learn: 0.2891797	total: 439ms	remaining: 18.7s
# 23:	learn: 0.2874226	total: 454ms	remaining: 18.5s
# 24:	learn: 0.2857579	total: 468ms	remaining: 18.3s
# 25:	learn: 0.2840927	total: 484ms	remaining: 18.1s
# 26:	learn: 0.2826039	total: 499ms	remaining: 18s
# 27:	learn: 0.2811202	total: 514ms	remaining: 17.8s
# 28:	learn: 0.2793808	total: 526ms	remaining: 17.6s
# 29:	learn: 0.2778773	total: 537ms	remaining: 17.4s
# 30:	learn: 0.2763553	total: 549ms	remaining: 17.1s
# 31:	learn: 0.2745459	total: 560ms	remaining: 16.9s
# 32:	learn: 0.2727081	total: 574ms	remaining: 16.8s
# 33:	learn: 0.2711625	total: 585ms	remaining: 16.6s
# 34:	learn: 0.2695335	total: 599ms	remaining: 16.5s
# 35:	learn: 0.2675868	total: 612ms	remaining: 16.4s
# 36:	learn: 0.2658407	total: 629ms	remaining: 16.4s
# 37:	learn: 0.2641304	total: 643ms	remaining: 16.3s
# 974:	learn: 0.0050701	total: 13.5s	remaining: 347ms
# 975:	learn: 0.0050320	total: 13.5s	remaining: 333ms
# 976:	learn: 0.0049932	total: 13.5s	remaining: 319ms
# 977:	learn: 0.0049610	total: 13.6s	remaining: 305ms
# 978:	learn: 0.0049285	total: 13.6s	remaining: 291ms
# 979:	learn: 0.0048944	total: 13.6s	remaining: 277ms
# 980:	learn: 0.0048671	total: 13.6s	remaining: 263ms
# 981:	learn: 0.0048354	total: 13.6s	remaining: 250ms
# 982:	learn: 0.0047977	total: 13.6s	remaining: 236ms
# 983:	learn: 0.0047672	total: 13.6s	remaining: 222ms
# 984:	learn: 0.0047307	total: 13.7s	remaining: 208ms
# 985:	learn: 0.0047053	total: 13.7s	remaining: 194ms
# 986:	learn: 0.0046732	total: 13.7s	remaining: 180ms
# 987:	learn: 0.0046433	total: 13.7s	remaining: 166ms
# 988:	learn: 0.0046124	total: 13.7s	remaining: 152ms
# 989:	learn: 0.0045848	total: 13.7s	remaining: 139ms
# 990:	learn: 0.0045615	total: 13.7s	remaining: 125ms
# 991:	learn: 0.0045325	total: 13.8s	remaining: 111ms
# 992:	learn: 0.0044988	total: 13.8s	remaining: 97.1ms
# 993:	learn: 0.0044679	total: 13.8s	remaining: 83.2ms
# 994:	learn: 0.0044305	total: 13.8s	remaining: 69.3ms
# 995:	learn: 0.0044002	total: 13.8s	remaining: 55.5ms
# 996:	learn: 0.0043698	total: 13.8s	remaining: 41.6ms
# 997:	learn: 0.0043384	total: 13.8s	remaining: 27.7ms
# 998:	learn: 0.0043095	total: 13.9s	remaining: 13.9ms
# 999:	learn: 0.0042829	total: 13.9s	remaining: 0us
# 0.004282903851060098Training error
# 0.004282903851060098Testing Error
# score 0.9999989336288088
# score 0.0185831229858876

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

model1 = RandomForestRegressor(random_state=1)
model2 = RandomForestRegressor(random_state=1)
model3 = RandomForestRegressor(random_state=1)

model12 = RandomForestRegressor(random_state=1)
model22 = RandomForestRegressor(random_state=1)
model32 = RandomForestRegressor(random_state=1)

lmr = VotingRegressor(estimators=[('rf1', model1), ('rf2', model2),('rf3', model3)])
lgr2= VotingRegressor(estimators=[('rf1', model1), ('rf2', model2),('rf3', model3)])

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('VotingRegressionPredictions1.csv')


lmr = VotingRegressor(estimators=[('rf1', model12), ('rf2', model22),('rf3', model32)])
lgr2= VotingRegressor(estimators=[('rf1', model12), ('rf2', model22),('rf3', model32)])


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('VotingRegressionPredictions2.csv')
# Out:
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.15090528302587367Training error
# 0.15090528302587367Testing Error
# score 0.7624008210135362
# score -0.20570081610068147
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/aaftab/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 2.088104275759817Training error
# 2.088104275759817Testing Error
# score 0.7465244234905002
# score -0.2744002769630869

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

model1 = GradientBoostingRegressor(random_state=1)
model2 = GradientBoostingRegressor(random_state=1)
model3 = GradientBoostingRegressor(random_state=1)

model12 = GradientBoostingRegressor(random_state=1)
model22 = GradientBoostingRegressor(random_state=1)
model32 = GradientBoostingRegressor(random_state=1)

lmr = VotingRegressor(estimators=[('gb', model1), ('rf', model2)])
lgr2= VotingRegressor(estimators=[('gb', model1), ('rf', model2)])

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('GBMVotingRegressionPredictions1.csv')


lmr = VotingRegressor(estimators=[('gb', model12), ('rf', model22)])
lgr2= VotingRegressor(estimators=[('gb', model12), ('rf', model22)])


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('GBMVotingRegressionPredictions2.csv')
# Out:
# 0.014270845900357676Training error
# 0.014270845900357676Testing Error
# score 0.9978751147574364
# score -0.09739467508200805
# 0.21025840826090939Training error
# 0.21025840826090939Testing Error
# score 0.9974299681898617
# score -0.1408442028794501

# %%
from catboost import CatBoostRegressor

lmr= CatBoostRegressor()
lgr2= CatBoostRegressor()

modellr = lmr.fit(features,results1)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results1, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('CatboostRegressionPredictions1.csv')


lmr = CatBoostRegressor()
lgr2= CatBoostRegressor()


modellr = lmr.fit(features,results2)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, results2, test_size=0.3, random_state=0)
modelval=lgr2.fit(X_train,y_train)
y_pred = modelval.predict(X_test)
y_pred2=modelval.predict(X_train)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

mse1=mean_squared_error(y_train, y_pred2)
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error')
mse2=mean_squared_error(y_test, y_pred)
rmse2=sqrt(mse1)
print(str(rmse2)+'Testing Error')

print ('score ' + str(modelval.score(X_train, y_train)))
print ('score '+str(modelval.score(X_test, y_test)))
        
predictions = modellr.predict(testfeatures)
pred=pd.DataFrame(predictions)
        
pred.to_csv('CatboostRegressionPredictions2.csv')
# Out:
# Learning rate set to 0.029308
# 0:	learn: 0.3317091	total: 131ms	remaining: 2m 10s
# 1:	learn: 0.3298378	total: 147ms	remaining: 1m 13s
# 2:	learn: 0.3277431	total: 167ms	remaining: 55.6s
# 3:	learn: 0.3257137	total: 186ms	remaining: 46.3s
# 4:	learn: 0.3238353	total: 209ms	remaining: 41.6s
# 5:	learn: 0.3221274	total: 229ms	remaining: 37.9s
# 6:	learn: 0.3199091	total: 245ms	remaining: 34.8s
# 7:	learn: 0.3177628	total: 263ms	remaining: 32.6s
# 8:	learn: 0.3160992	total: 279ms	remaining: 30.7s
# 9:	learn: 0.3139354	total: 298ms	remaining: 29.5s
# 10:	learn: 0.3117400	total: 316ms	remaining: 28.4s
# 11:	learn: 0.3095337	total: 335ms	remaining: 27.6s
# 12:	learn: 0.3074844	total: 353ms	remaining: 26.8s
# 13:	learn: 0.3056003	total: 375ms	remaining: 26.4s
# 14:	learn: 0.3035581	total: 401ms	remaining: 26.4s
# 15:	learn: 0.3014468	total: 435ms	remaining: 26.7s
# 16:	learn: 0.2999775	total: 466ms	remaining: 27s
# 17:	learn: 0.2982461	total: 494ms	remaining: 27s
# 909:	learn: 0.0007447	total: 19.9s	remaining: 1.97s
# 910:	learn: 0.0007390	total: 19.9s	remaining: 1.95s
# 911:	learn: 0.0007367	total: 19.9s	remaining: 1.92s
# 912:	learn: 0.0007320	total: 19.9s	remaining: 1.9s
# 913:	learn: 0.0007271	total: 20s	remaining: 1.88s
# 914:	learn: 0.0007231	total: 20s	remaining: 1.86s
# 915:	learn: 0.0007193	total: 20s	remaining: 1.83s
# 916:	learn: 0.0007143	total: 20s	remaining: 1.81s
# 917:	learn: 0.0007103	total: 20s	remaining: 1.79s
# 918:	learn: 0.0007051	total: 20.1s	remaining: 1.77s
# 919:	learn: 0.0007003	total: 20.1s	remaining: 1.75s
# 920:	learn: 0.0006966	total: 20.1s	remaining: 1.72s
# 921:	learn: 0.0006921	total: 20.1s	remaining: 1.7s
# 922:	learn: 0.0006874	total: 20.1s	remaining: 1.68s
# 923:	learn: 0.0006834	total: 20.2s	remaining: 1.66s
# 924:	learn: 0.0006793	total: 20.2s	remaining: 1.64s
# 925:	learn: 0.0006761	total: 20.2s	remaining: 1.61s
# 926:	learn: 0.0006716	total: 20.2s	remaining: 1.59s
# 927:	learn: 0.0006674	total: 20.3s	remaining: 1.57s
# 928:	learn: 0.0006626	total: 20.3s	remaining: 1.55s
# 929:	learn: 0.0006585	total: 20.3s	remaining: 1.53s
# ...
# 693:	learn: 0.0338383	total: 14s	remaining: 6.18s
# 694:	learn: 0.0335904	total: 14s	remaining: 6.16s
# 695:	learn: 0.0333590	total: 14.1s	remaining: 6.14s
# 696:	learn: 0.0330926	total: 14.1s	remaining: 6.12s
# 697:	learn: 0.0328257	total: 14.1s	remaining: 6.1s
# 698:	learn: 0.0325964	total: 14.1s	remaining: 6.08s
# 699:	learn: 0.0323732	total: 14.1s	remaining: 6.06s
# 700:	learn: 0.0321691	total: 14.2s	remaining: 6.04s
# 701:	learn: 0.0319332	total: 14.2s	remaining: 6.02s
# 702:	learn: 0.0317426	total: 14.2s	remaining: 6s
# 703:	learn: 0.0315035	total: 14.2s	remaining: 5.97s
# 704:	learn: 0.0312895	total: 14.2s	remaining: 5.95s
# 705:	learn: 0.0310718	total: 14.3s	remaining: 5.93s
# 706:	learn: 0.0308622	total: 14.3s	remaining: 5.91s
# 707:	learn: 0.0306592	total: 14.3s	remaining: 5.89s
# 708:	learn: 0.0304436	total: 14.3s	remaining: 5.87s
# 709:	learn: 0.0302691	total: 14.3s	remaining: 5.85s
# 710:	learn: 0.0300413	total: 14.3s	remaining: 5.83s
# 711:	learn: 0.0298436	total: 14.4s	remaining: 5.81s
# 712:	learn: 0.0296312	total: 14.4s	remaining: 5.79s
# 713:	learn: 0.0294331	total: 14.4s	remaining: 5.76s
# 714:	learn: 0.0292296	total: 14.4s	remaining: 5.75s
# 715:	learn: 0.0290076	total: 14.4s	remaining: 5.72s
# 716:	learn: 0.0287972	total: 14.5s	remaining: 5.71s
# 717:	learn: 0.0285954	total: 14.5s	remaining: 5.69s
# 718:	learn: 0.0283891	total: 14.5s	remaining: 5.67s
