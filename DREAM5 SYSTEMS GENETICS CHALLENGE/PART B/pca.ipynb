# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

trdt=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/TrainingGenotype.csv')
tstdt=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/TestingGenotype.csv')

features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

# %%
#pca on pcadf
pca=PCA().fit(features)

#Plotting the Cumulative Summation of the Explained Variance
plt.figure()

plt.xlim(0.0,4)
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('destinations variance')
plt.show()

# %%
#pca on pcadf
pca=PCA().fit(testfeatures)

#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.xlim(0.0,4)
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('destinations variance')
plt.show()

# %%
from sklearn.decomposition import PCA
pca1 = PCA(n_components = 1)
pca = PCA(n_components = 1)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2689188242933486Training error 1
# 3.700790344867241Training error 2

# %%
#without pca
results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.26776440588385403Training error 1
# 5.424376668837783Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)
from sklearn.decomposition import PCA
pca1 = PCA(n_components = 2)
pca = PCA(n_components = 2)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.26776440588385403Training error 1
# 3.6928995339410924Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 3)
pca = PCA(n_components = 3)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2789484816095283Training error 1
# 3.6840426042551475Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 4)
pca = PCA(n_components = 4)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.28275950470693534Training error 1
# 3.8663997619138746Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 5)
pca = PCA(n_components = 5)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2669602944825357Training error 1
# 3.856164770250881Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 6)
pca = PCA(n_components = 6)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2828265263391746Training error 1
# 3.864272308567046Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 7)
pca = PCA(n_components = 7)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.LinearRegression()
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2821907814891647Training error 1
# 3.8797944627276415Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 8)
pca = PCA(n_components = 8)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.Lasso(alpha=0.1)
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.2822557766759494Training error 1
# 3.8870350036217705Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components = 20)
pca = PCA(n_components = 20)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import linear_model

lmr1=linear_model.Lasso(alpha=0.1)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = linear_model.Lasso(alpha=0.1)
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.28244635227480647Training error 1
# 3.9604061258709846Training error 2

# %%
features=trdt.copy()

features.drop('Phenotype1',axis=1,inplace=True)
features.drop('Phenotype2',axis=1,inplace=True)
features.drop('Plant',axis=1,inplace=True)


testfeatures=tstdt.copy()
testfeatures.drop('Plant',axis=1,inplace=True)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn import preprocessing
standard= preprocessing.StandardScaler()

features = standard.fit_transform(features)
testfeatures=standard.fit_transform(testfeatures)

features=pd.DataFrame(features)
testfeatures=pd.DataFrame(testfeatures)

from sklearn.decomposition import PCA
pca1 = PCA(n_components =4)
pca = PCA(n_components = 4)

pca.fit(features)
pca1.fit(testfeatures)
features=pca.fit_transform(features)
testfeatures=pca.fit_transform(testfeatures)

results1=trdt['Phenotype1']
results2=trdt['Phenotype2']

from sklearn.linear_model import ElasticNetCV

lmr1=ElasticNetCV(cv=10, random_state=0)
modellr1 = lmr1.fit(features,results1)

predictions1 = modellr1.predict(testfeatures)
pred1=pd.DataFrame(predictions1)
        
pred1.to_csv('Lasso.csv')


lmr2 = ElasticNetCV(cv=10, random_state=0)
modellr2 = lmr2.fit(features,results2)

predictions2 = modellr2.predict(testfeatures)
pred2=pd.DataFrame(predictions2)
        
pred2.to_csv('Lasso2.csv')

predic1=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso.csv')
predic2=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/Lasso2.csv')

gold=pd.read_csv('/home/aaftab/Github/Computational-Systems-Biology-Project/DREAM5 SYSTEMS GENETICS CHALLENGE/PART B/DREAM5_SysGenB_GoldStandard/DREAM5_SysGenB1_GoldStandard.csv', sep='\t')
gold.drop(gold.columns[-1],axis=1,inplace=True)

import math
from math import sqrt
from sklearn.metrics import mean_squared_error

y_pred1=predic1.iloc[:,1]
y_pred2=predic2.iloc[:,1]

gold1=gold.iloc[0,:]
gold1=gold1.values

gold2=gold.iloc[1,:]
gold2=gold2.values

mse1=mean_squared_error(y_pred1, np.transpose(gold1))
rmse1=sqrt(mse1)
print(str(rmse1)+'Training error 1')

mse2=mean_squared_error(y_pred2,np.transpose(gold2))
rmse2=sqrt(mse2)
print(str(rmse2)+'Training error 2')
# Out:
# 0.26537479655533236Training error 1
# 3.703276110125784Training error 2
